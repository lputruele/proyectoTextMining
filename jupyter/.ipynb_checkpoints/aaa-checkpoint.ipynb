# %% [markdown]
# # Comparación de grafos en Twitter para detección de posicionamientos
#
# ***Proyecto de la asignatura de Text Mining para la carrera de Doctorado en Ciencias de la Computación (FAMAF).***
#
# Este trabajo consiste en encontrar comunidades a favor y en contra sobre un tópico, en este caso el aborto.
#
# El enfoque utilizado consiste en generar un grafo donde los nodos son tweets de un dataset y en donde los arcos que los unen representan n-gramas en común. Mientras mas n-gramas en común, más peso tiene el arco. En este trabajo se comparan bigramas, trigramas y cuadrigramas.
#
# Los n-gramas a considerar son los que tienen mejor ranking en base a alguna métrica de asociación. Se comparan en este trabajo 6 métricas: pmi, chi-squared, poisson stirling, likelihood ratio, student-t y jacard.
#
# El grafo luego se particiona en base a un algoritmo de detección de comunidades, y finalmente se evaluan estas particiones contra el mismo dataset pero etiquetado.

# %% [markdown]
# ***Librerias a utilizar***

# %%
import nltk
import sys
import re
import numpy
import pandas
from nltk.util import ngrams
from nltk import FreqDist
from nltk.tokenize import word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.collocations import BigramCollocationFinder
from nltk.collocations import TrigramCollocationFinder
from nltk.collocations import QuadgramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.metrics import TrigramAssocMeasures
from nltk.metrics import QuadgramAssocMeasures
from nltk.sentiment.util import extract_unigram_feats
from nltk.sentiment.util import extract_bigram_feats
from nltk.corpus import stopwords
from pysentimiento.preprocessing import preprocess_tweet
from pysentimiento import analyzer
import json
import networkx as nx
import community as community_louvain
import networkx.algorithms.community.kernighan_lin as community_alg
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %% [markdown]
# ***Definición de funciones a utilizar***

# %%
def preprocess(doc):
    pdoc = preprocess_tweet(doc, shorten=2) #standarize retweets,urls,responses,laughs,emojis,etc
    pdoc = pdoc.lower() #lowercase
    pdoc = re.sub(r'[^\w\s]', '', pdoc) #remove punctuation
    pdoc = ' '.join([w for w in pdoc.split() if w not in stopwords])
    return pdoc

def remove_duplicates(x):
    return list(dict.fromkeys(x))

def get_ngrams(words, top_n, min_freq, option, measure):
    if (option==2):
        bcf = BigramCollocationFinder.from_words(iter(words))
        bcf.apply_freq_filter(min_freq)
        bigrams = []
        if (measure=="pmi"):
            print ("Using pmi assoc. measure...")
            bigrams = bcf.nbest(BigramAssocMeasures.pmi, top_n)
        if (measure=="chi"):
            print ("Using chi-squared measure...")
            bigrams = bcf.nbest(BigramAssocMeasures.chi_sq, top_n)
        if (measure=="lr"):
            print ("Using likelihood ratio assoc. measure...")
            bigrams = bcf.nbest(BigramAssocMeasures.likelihood_ratio, top_n)
        if (measure=="ps"):
            print ("Using poisson stirling assoc. measure...")
            bigrams = bcf.nbest(BigramAssocMeasures.poisson_stirling, top_n)
        if (measure=="j"):
            print ("Using jaccard assoc. measure...")
            bigrams = bcf.nbest(BigramAssocMeasures.jaccard, top_n)
        if (measure=="st"):
            print ("Using student_t assoc. measure...")
            bigrams = bcf.nbest(BigramAssocMeasures.student_t, top_n)
        print("top "+str(top_n)+" bigrams:")
        print(bigrams)
        return bigrams
    if (option==3):
        tcf = TrigramCollocationFinder.from_words(iter(words))
        tcf.apply_freq_filter(min_freq)
        trigrams = []
        if (measure=="pmi"):
            print ("Using pmi assoc. measure...")
            trigrams = tcf.nbest(TrigramAssocMeasures.pmi, top_n)
        if (measure=="chi"):
            print ("Using chi-squared measure...")
            trigrams = tcf.nbest(TrigramAssocMeasures.chi_sq, top_n)
        if (measure=="lr"):
            print ("Using likelihood ratio assoc. measure...")
            trigrams = tcf.nbest(TrigramAssocMeasures.likelihood_ratio, top_n)
        if (measure=="ps"):
            print ("Using poisson stirling assoc. measure...")
            trigrams = tcf.nbest(TrigramAssocMeasures.poisson_stirling, top_n)
        if (measure=="j"):
            print ("Using jaccard assoc. measure...")
            trigrams = tcf.nbest(TrigramAssocMeasures.jaccard, top_n)
        if (measure=="st"):
            print ("Using student_t assoc. measure...")
            trigrams = tcf.nbest(TrigramAssocMeasures.student_t, top_n)
        print("top "+str(top_n)+" trigrams:")
        print(trigrams)
        return trigrams
    if (option==4):
        qcf = QuadgramCollocationFinder.from_words(iter(words))
        qcf.apply_freq_filter(min_freq)
        quadgrams = []
        if (measure=="pmi"):
            print ("Using pmi assoc. measure...")
            quadgrams = qcf.nbest(QuadgramAssocMeasures.pmi, top_n)
        if (measure=="chi"):
            print ("Using chi-squared measure...")
            quadgrams = qcf.nbest(QuadgramAssocMeasures.chi_sq, top_n)
        if (measure=="lr"):
            print ("Using likelihood ratio assoc. measure...")
            quadgrams = qcf.nbest(QuadgramAssocMeasures.likelihood_ratio, top_n)
        if (measure=="ps"):
            print ("Using poisson stirling assoc. measure...")
            quadgrams = qcf.nbest(QuadgramAssocMeasures.poisson_stirling, top_n)
        if (measure=="j"):
            print ("Using jaccard assoc. measure...")
            quadgrams = qcf.nbest(QuadgramAssocMeasures.jaccard, top_n)
        if (measure=="st"):
            print ("Using student_t assoc. measure...")
            quadgrams = qcf.nbest(QuadgramAssocMeasures.student_t, top_n)
        print("top "+str(top_n)+" quadgrams:")
        print(quadgrams)
        return quadgrams

def extract_ngram_feats(document, ngramss, option):
    features = {}
    for ngram in ngramss:
        if option==2:
            features['contains({0} - {1})'.format(ngram[0], ngram[1])] = ngram in nltk.bigrams(document)
        if option==3:
            features['contains({0} - {1} - {2})'.format(ngram[0], ngram[1], ngram[2])] = ngram in nltk.trigrams(document)
        if option==4:
            features['contains({0} - {1} - {2} - {3})'.format(ngram[0], ngram[1], ngram[2], ngram[3])] = ngram in ngrams(document, 4)
    return features

def create_graph(words, option, top_n,measure):
    # Extract ngram features
    ngramss,matrix = create_matrix(words,option, top_n,measure)
    G = nx.Graph()
    for d in range(len(documents)):
        G.add_node(d,tweet=documents[d], ptweet=documents_processed[d])
    for d1 in range(len(documents)):
        for d2 in range(len(documents)):
            for ngram in ngramss:
                feat_key = ""
                if option==2:
                    feat_key = "contains("+ngram[0]+" - "+ngram[1]+")"
                if option==3:
                    feat_key = "contains("+ngram[0]+" - "+ngram[1]+" - "+ngram[2]+")"
                if option==4:
                    feat_key = "contains("+ngram[0]+" - "+ngram[1]+" - "+ngram[2]+" - "+ngram[3]+")"
                if (matrix[d1][feat_key] and matrix[d2][feat_key]) and (d1!=d2):
                    oldEdge = (d1,d2) if (d1,d2) in G.edges else None
                    if oldEdge==None:
                        G.add_edge(d1,d2,weight=1)
                    else:
                        G.adj[d1][d2]['weight'] += 1
    return G

def create_matrix(words,option,top_n,measure):
    ngramss = get_ngrams(words,top_n,1,option,measure)
    matrix = []
    for d in documents_processed:
        matrix.append(extract_ngram_feats(d.split(),ngramss,option))
    return ngramss,matrix;


def draw_graph(G,partition):
    pos = nx.spring_layout(G)
    #color the nodes according to their partition
    cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
    nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=10,cmap=cmap, node_color=list(partition.values()))
    nx.draw_networkx_edges(G, pos, alpha=0.5)
    nx.write_gexf(G, "test.gexf")
    plt.show()

# %% [markdown]
# ***Main***
#
# Abrimos el dataset de tweets, eliminamos tweets duplicados, esto nos deja 1607 tweets.

# %%
f = open('tweets.json',)
data = json.load(f)
documents = remove_duplicates([d['text'] for d in data])
f.close()

# %% [markdown]
# Adaptamos los stopwords tradicionales para que no incluyan palabras que puedan ayudar a detectar sentimiento, y que a su vez incluyan tags innecesarios.
#
# Luego preprocesamos los tweets, esto implica:
#  - estandarizar retweets, urls, respuestas, risas y emojis
#  - pasar todo a minuscula
#  - eliminar signos de puntuación
#  - eliminar stopwords

# %%
exceptions = ['no','pero','muy','sin','y','ni','contra','tanto','ellas','nosotras','nuestra','nuestras']
stopwords = [x for x in stopwords.words('spanish') if x not in exceptions]
stopwords.append('rt')
stopwords.append('usuario')
stopwords.append('url')
stopwords.append('re')
stopwords.append('emoji')
documents_processed = [preprocess(d) for d in documents]

print("Ejemplo de tweet original:"+ documents[0])
print("Ejemplo de tweet procesado:"+documents_processed[0])
print("Cantidad de tweets:"+ str(len (documents)))
print("Cantidad de tweets (procesados):"+ str(len (documents_processed)))
# Out:
# Ejemplo de tweet original:RT @LAM_Oficial: ¡Si a la Vida!¡No al aborto! #NoAlAborto
# Ejemplo de tweet procesado:si vidano aborto no aborto
# Cantidad de tweets:1607
# Cantidad de tweets (procesados):1607

# %% [markdown]
# Separamos tweets a favor y en contra (los primeros 785 tweets están etiquetados en contra, y el resto a favor). Esto nos sirve para luego validar los resultados.

# %%
tweets_en_contra = documents[:785]
tweets_a_favor = documents[785:]

# %% [markdown]
# Tokenizamos todos los tweets

# %%
doc = ' '.join(documents_processed)
tokenizer = RegexpTokenizer(r'\w+')
words = tokenizer.tokenize(doc)

# %% [markdown]
# Creamos un grafo donde los nodos son los tweets y los arcos representan n-gramas en común. Mientras más haya en común el arco se hace linearmente mas pesado. Aquí hay tres argumentos importantes:
# - n
#   - 2 (bigramas)
#   - 3 (trigramas)
#   - 4 (cuatrigramas)
# - número de n-gramas a considerar como features de acuerdo a la métrica de asociación
# - metrica de asociación
#   - pmi (pointwise mutual information)
#   - chi (chi-squared)
#   - j (jaccard)
#   - ps (poisson-stirling)
#   - st (student-t)
#   - lr (likelihood ratio)
#
# Aqui, la configuracion es de n=2, 20 bigramas, y usando la métrica likelihood ratio.

# %%
G = create_graph(words,2,20,"lr")
print("Cantidad de nodos:" + str(G.number_of_nodes()))
print("Cantidad de arcos:" + str(G.number_of_edges()))
# Out:
# Using likelihood ratio assoc. measure...
# top 20 bigrams:
# [('aborto', 'legal'), ('ala', 'vida'), ('si', 'ala'), ('no', 'aborto'), ('banco', 'avilma'), ('salvemos', 'las2'), ('las2', 'vidas'), ('dorso', 'mano'), ('hacia', 'abajo'), ('mano', 'índice'), ('educación', 'sexual'), ('corazón', 'verde'), ('tono', 'piel'), ('índice', 'hacia'), ('manos', 'aplaudiendo'), ('marca', 'cruz'), ('sia', 'vida'), ('santa', 'fe'), ('bíceps', 'flexionado'), ('vida', 'no')]
# Cantidad de nodos:1607
# Cantidad de arcos:184743

# %% [markdown]
# Realizamos una partición del grafo utilizando el algoritmo de bisección de kernighan. Esto nos parte el grafo en exactamente 2 conjuntos.
# Luego evaluamos la precisión de cada partición respecto a los tweets que sabemos que estan a favor y en contra respectivamente.
# Poniendo un limite de 500 iteraciones al algoritmo de kernighan nos da el mejor resultado experimental (una precisión de 75-80%).

# %%
partition = community_alg.kernighan_lin_bisection(G,max_iter=500,weight='weight')

en_contra_p0 = 0
a_favor_p0 = 0
en_contra_p1 = 0
a_favor_p1= 0

for d in partition[0]:
    if (documents[d] in tweets_en_contra):
        en_contra_p0 += 1
    if (documents[d] in tweets_a_favor):
        a_favor_p0 += 1
for d in partition[1]:
    if (documents[d] in tweets_en_contra):
        en_contra_p1 += 1
    if (documents[d] in tweets_a_favor):
        a_favor_p1 += 1
    
print("particion 0:")
print("  tweets a favor:" + str(a_favor_p0) + "("+str((a_favor_p0/(a_favor_p0+en_contra_p0))*100)+"%)")
print("  tweets en contra:" + str(en_contra_p0) + "("+str((en_contra_p0/(a_favor_p0+en_contra_p0))*100)+"%)")
print("particion 1:")
print("  tweets a favor:" + str(a_favor_p1) + "("+str((a_favor_p1/(a_favor_p1+en_contra_p1))*100)+"%)")
print("  tweets en contra:" + str(en_contra_p1) + "("+str((en_contra_p1/(a_favor_p1+en_contra_p1))*100)+"%)")
# Out:
# particion 0:
#   tweets a favor:177(22.04234122042341%)
#   tweets en contra:626(77.95765877957659%)
# particion 1:
#   tweets a favor:645(80.22388059701493%)
#   tweets en contra:159(19.776119402985074%)

# %% [markdown]
#  El fragmento de debajo genera un gráfico mostrando la partición (No se ve muy claro).

# %%
partition_dict = []
for d in partition[0]:
    partition_dict.append((d,0))
for d in partition[1]:
    partition_dict.append((d,1))
draw_graph(G,dict(partition_dict))

# %% [markdown]
# # Experimentos
#
# Como se puede observar, los mejores resultados se consiguen utilizando bigramas con metricas de asociación likelihood_ratio, poisson stirling o student_t. A partir de los 20, la cantidad de bigramas a considerar no mejora significativamente los resultados. En general, lo que se busca es que el grafo sea lo suficientemente denso (muchos arcos) con información relevante (n-gramas significativos) para que la partición sea de calidad. Por practicidad, todos los experimentos de esta sección tienen un limite de 100 iteraciones en el algoritmo de particionado.
#
# ---
#
# - ***features***: 20 top bigrams with likelihood_ratio
# [('aborto', 'legal'), ('ala', 'vida'), ('si', 'ala'), ('no', 'aborto'), ('banco', 'avilma'), ('salvemos', 'las2'), ('las2', 'vidas'), ('dorso', 'mano'), ('hacia', 'abajo'), ('mano', 'índice'), ('educación', 'sexual'), ('corazón', 'verde'), ('tono', 'piel'), ('índice', 'hacia'), ('manos', 'aplaudiendo'), ('marca', 'cruz'), ('sia', 'vida'), ('santa', 'fe'), ('bíceps', 'flexionado'), ('vida', 'no')]
# - Number of nodes:1607
# - Number of edges:184743
# - ***particion 0***:
#   - tweets a favor: 508 (63.26276463262764%)
#   - tweets en contra: 295 (36.73723536737236%)
# - ***particion 1***:
#   - tweets a favor: 314 (39.0547263681592%)
#   - tweets en contra: 490 (60.94527363184079%)
#
# ---
#
# - ***features***: 20 top bigrams with poisson stirling
# [('aborto', 'legal'), ('no', 'aborto'), ('si', 'ala'), ('ala', 'vida'), ('banco', 'avilma'), ('salvemos', 'las2'), ('las2', 'vidas'), ('dorso', 'mano'), ('mano', 'índice'), ('educación', 'sexual'), ('corazón', 'verde'), ('hacia', 'abajo'), ('índice', 'hacia'), ('tono', 'piel'), ('manos', 'aplaudiendo'), ('vida', 'no'), ('marca', 'cruz'), ('sia', 'vida'), ('santa', 'fe'), ('ser', 'humano')]
# - Number of nodes:1607
# - Number of edges:184874
# - ***particion 0***:
#   - tweets a favor: 520 (64.75716064757161%)
#   - tweets en contra: 283 (35.2428393524284%)
# - ***particion 1***:
#   - tweets a favor: 302 (37.56218905472637%)
#   - tweets en contra: 502 (62.43781094527363%)
#
# ---
#
# - ***features***: 20 top bigrams with student_t
# [('aborto', 'legal'), ('no', 'aborto'), ('ala', 'vida'), ('si', 'ala'), ('vida', 'no'), ('banco', 'avilma'), ('salvemos', 'las2'), ('las2', 'vidas'), ('aborto', 'si'), ('y', 'gratuito'), ('corazón', 'verde'), ('sia', 'vida'), ('noal', 'aborto'), ('dorso', 'mano'), ('mano', 'índice'), ('educación', 'sexual'), ('hacia', 'abajo'), ('índice', 'hacia'), ('legal', 'seguro'), ('tono', 'piel')]
# - Number of nodes:1607
# - Number of edges:185495
# - ***particion 0***:
#   - tweets a favor: 296 (36.86176836861768%)
#   - tweets en contra: 507 (63.13823163138231%)
# - ***particion 1***:
#   - tweets a favor: 526 (65.4228855721393%)
#   - tweets en contra: 278 (34.57711442786069%)
#
# ---
#
# - ***features***: 20 top bigrams with pmi
# [('0', 'aporte'), ('100s', 'of'), ('1favor', 'pon'), ('20yearold', 'woman'), ('3015', 'bhti'), ('50', 'decidió'), ('8418', 'sigu'), ('96', 'camila'), ('abortas', 'matas'), ('abortazo', 'perdio'), ('abortogratuito', 'exclamación'), ('abrir', 'piernas'), ('absorber', 'androides'), ('absurdo', 'campañas'), ('acertada', 'comparaciónpermitame'), ('acompañamiento', 'comi'), ('actividad', 'cumpleaños'), ('acusar', 'damas'), ('adolescencia', 'cuestione'), ('advirtió', 'comediante')]
# - Number of nodes:1607
# - Number of edges:0
# - ***particion 0***:
#   - tweets a favor: 410 (51.05853051058531%)
#   - tweets en contra: 393 (48.94146948941469%)
# - ***particion 1***:
#   - tweets a favor: 412 (51.243781094527364%)
#   - tweets en contra: 392 (48.756218905472636%)
#
# ---
#
# - ***features***: 20 top bigrams with chi-squared
# [('0', 'aporte'), ('100s', 'of'), ('16hs', 'convoca'), ('1favor', 'pon'), ('20', 'hs'), ('20yearold', 'woman'), ('3015', 'bhti'), ('50', 'decidió'), ('8418', 'sigu'), ('96', 'camila'), ('abortas', 'matas'), ('abortazo', 'perdio'), ('abortogratuito', 'exclamación'), ('aborté', 'recuerdos'), ('abrir', 'piernas'), ('absorber', 'androides'), ('absurdo', 'campañas'), ('acertada', 'comparaciónpermitame'), ('acompañamiento', 'comi'), ('actitudes', 'nefastas')]
# - Number of nodes:1607
# - Number of edges:4
# - ***particion 0***:
#   - tweets a favor:426 (53.05105853051059%)
#   - tweets en contra:377 (46.94894146948941%)
# - ***particion 1***:
#   - tweets a favor:396 (49.25373134328358%)
#   - tweets en contra:408 (50.74626865671642%)
#
# ---
#
# - ***features***: 20 top bigrams with jaccard
# [('0', 'aporte'), ('100s', 'of'), ('16hs', 'convoca'), ('1favor', 'pon'), ('20', 'hs'), ('20yearold', 'woman'), ('3015', 'bhti'), ('50', 'decidió'), ('8418', 'sigu'), ('96', 'camila'), ('abortas', 'matas'), ('abortazo', 'perdio'), ('abortogratuito', 'exclamación'), ('aborté', 'recuerdos'), ('abrir', 'piernas'), ('absorber', 'androides'), ('absurdo', 'campañas'), ('acertada', 'comparaciónpermitame'), ('acompañamiento', 'comi'), ('actitudes', 'nefastas')]
# - Number of nodes:1607
# - Number of edges:4
# - ***particion 0***:
#   - tweets a favor:420 (52.3038605230386%)
#   - tweets en contra:383 (47.6961394769614%)
# - ***particion 1***:
#   - tweets a favor:402 (50.0%)
#   - tweets en contra:402 (50.0%)
#
# ---
#
# - ***features***: 50 top bigrams with likelihood_ratio
# [('aborto', 'legal'), ('ala', 'vida'), ('si', 'ala'), ('no', 'aborto'), ('banco', 'avilma'), ('salvemos', 'las2'), ('las2', 'vidas'), ('dorso', 'mano'), ('hacia', 'abajo'), ('mano', 'índice'), ('educación', 'sexual'), ('corazón', 'verde'), ('tono', 'piel'), ('índice', 'hacia'), ('manos', 'aplaudiendo'), ('marca', 'cruz'), ('sia', 'vida'), ('santa', 'fe'), ('bíceps', 'flexionado'), ('vida', 'no'), ('y', 'gratuito'), ('academia', 'nacional'), ('ser', 'humano'), ('piel', 'claro'), ('noal', 'aborto'), ('nacional', 'medicina'), ('sexual', 'decidir'), ('decidir', 'anticonceptivos'), ('seguro', 'ygratuito'), ('colegio', 'médico'), ('derechos', 'humanos'), ('legal', 'seguro'), ('aborto', 'aborto'), ('nuestra', 'compañera'), ('círculo', 'rojo'), ('claro', 'medio'), ('vilma', 'ripoll'), ('voz', 'kyosko'), ('flecha', 'hacia'), ('puño', 'alto'), ('rojo', 'grande'), ('aplaudiendo', 'manos'), ('hacia', 'arriba'), ('buen', 'lunes'), ('aborto', 'si'), ('salud', 'pública'), ('abortos', 'clandestinos'), ('seguro', 'y'), ('inseguro', '28'), ('maría', 'campos')]
# - Number of nodes:1607
# - Number of edges:186048
# - ***particion 0***:
#   - tweets a favor: 307 (38.23163138231631%)
#   - tweets en contra: 496 (61.76836861768369%)
# - ***particion 1***:
#   - tweets a favor: 515 (64.05472636815921%)
#   - tweets en contra: 289 (35.9452736318408%)
#
# ---
#
# - ***features***: 100 top bigrams with likelihood_ratio
# [('aborto', 'legal'), ('ala', 'vida'), ('si', 'ala'), ('no', 'aborto'), ('banco', 'avilma'), ('salvemos', 'las2'), ('las2', 'vidas'), ('dorso', 'mano'), ('hacia', 'abajo'), ('mano', 'índice'), ('educación', 'sexual'), ('corazón', 'verde'), ('tono', 'piel'), ('índice', 'hacia'), ('manos', 'aplaudiendo'), ('marca', 'cruz'), ('sia', 'vida'), ('santa', 'fe'), ('bíceps', 'flexionado'), ('vida', 'no'), ('y', 'gratuito'), ('academia', 'nacional'), ('ser', 'humano'), ('piel', 'claro'), ('noal', 'aborto'), ('nacional', 'medicina'), ('sexual', 'decidir'), ('decidir', 'anticonceptivos'), ('seguro', 'ygratuito'), ('colegio', 'médico'), ('derechos', 'humanos'), ('legal', 'seguro'), ('aborto', 'aborto'), ('nuestra', 'compañera'), ('círculo', 'rojo'), ('claro', 'medio'), ('vilma', 'ripoll'), ('voz', 'kyosko'), ('flecha', 'hacia'), ('puño', 'alto'), ('rojo', 'grande'), ('aplaudiendo', 'manos'), ('hacia', 'arriba'), ('buen', 'lunes'), ('aborto', 'si'), ('salud', 'pública'), ('abortos', 'clandestinos'), ('seguro', 'y'), ('inseguro', '28'), ('maría', 'campos'), ('selfie', 'maría'), ('cara', 'llorando'), ('pro', 'vida'), ('amalia', 'granata'), ('pañuelo', 'verde'), ('objetores', 'conciencia'), ('ginecólogos', 'objetores'), ('villa', '31'), ('somoslavozdelosquenotienenvoz', 'noal'), ('primera', 'semana'), ('marco', 'debate'), ('buenlunes', 'atr'), ('desaparecen', 'protege'), ('facultad', 'psicología'), ('pastora', 'pentecostal'), ('planilla', 'colaborativa'), ('protege', 'violentos'), ('psicología', 'unc'), ('llorando', 'risa'), ('seres', 'humanos'), ('tocan', 'respondemos'), ('médico', 'salvador'), ('botón', 'marca'), ('ni', 'menos'), ('vidas', 'somoslavozdelosquenotienenvoz'), ('no', 'morir'), ('ataca', 'defiendo'), ('campos', 'rodeada'), ('hijas', 'murió'), ('rodeada', '5'), ('solicitada', 'publicada'), ('manos', 'oración'), ('debo', 'decir'), ('kyosko', 'si'), ('podemos', 'hablar'), ('presidente', 'macri'), ('doble', 'moral'), ('médicos', 'ginecólogos'), ('defensa', 'vida'), ('pide', 'apoyo'), ('editorial', 'dimension'), ('lorena', 'fernandez'), ('5', 'hijas'), ('luchemos', 'juntos'), ('romero', 'ataca'), ('haciendo', 'mueca'), ('preguntar', 'novaresio'), ('semana', 'debate'), ('pasó', 'congreso'), ('mano', 'levantada')]
# - Number of nodes: 1607
# - Number of edges: 186357
# - ***particion 0***:
#   - tweets a favor: 521 (64.88169364881693%)
#   - tweets en contra: 282 (35.118306351183065%)
# - ***particion 1***:
#   - tweets a favor: 301 (37.43781094527363%)
#   - tweets en contra: 503 (62.56218905472637%)
#
# ---
#
# - ***features***: 20 top trigrams with likelihood_ratio
# [('no', 'aborto', 'legal'), ('aborto', 'legal', 'seguro'), ('aborto', 'aborto', 'legal'), ('avilma', 'aborto', 'legal'), ('debate', 'aborto', 'legal'), ('favor', 'aborto', 'legal'), ('despenalización', 'aborto', 'legal'), ('verde', 'aborto', 'legal'), ('x', 'aborto', 'legal'), ('aborto', 'legal', 'ahora'), ('aborto', 'legal', 'abortolegalya'), ('y', 'aborto', 'legal'), ('vida', 'aborto', 'legal'), ('debatiendo', 'aborto', 'legal'), ('ygratuito', 'aborto', 'legal'), ('aborto', 'legal', 'dorso'), ('aborto', 'legal', 'vida'), ('aborto', 'legal', 'y'), ('abortolegalseguroygratuito', 'aborto', 'legal'), ('aborto', 'legal', 'derechoadecidir')]
# - Number of nodes: 1607
# - Number of edges: 1366
# - ***particion 0***:
#   - tweets a favor: 412 (51.30759651307597%)
#   - tweets en contra: 391 (48.692403486924036%)
# - ***particion 1***:
#   - tweets a favor: 410 (50.99502487562189%)
#   - tweets en contra: 394 (49.004975124378106%)
#
# ---
#
# - ***features***: 50 top trigrams with likelihood_ratio
# [('no', 'aborto', 'legal'), ('aborto', 'legal', 'seguro'), ('aborto', 'aborto', 'legal'), ('avilma', 'aborto', 'legal'), ('debate', 'aborto', 'legal'), ('favor', 'aborto', 'legal'), ('despenalización', 'aborto', 'legal'), ('verde', 'aborto', 'legal'), ('x', 'aborto', 'legal'), ('aborto', 'legal', 'ahora'), ('aborto', 'legal', 'abortolegalya'), ('y', 'aborto', 'legal'), ('vida', 'aborto', 'legal'), ('debatiendo', 'aborto', 'legal'), ('ygratuito', 'aborto', 'legal'), ('aborto', 'legal', 'dorso'), ('aborto', 'legal', 'vida'), ('aborto', 'legal', 'y'), ('abortolegalseguroygratuito', 'aborto', 'legal'), ('aborto', 'legal', 'derechoadecidir'), ('legal', 'aborto', 'legal'), ('aborto', 'legal', 'ciencia'), ('aborto', 'legal', 'banco'), ('congreso', 'aborto', 'legal'), ('ley', 'aborto', 'legal'), ('aborto', 'legal', 'argentina'), ('aborto', 'legal', 'corazón'), ('aborto', 'legal', 'flecha'), ('aborto', 'legal', 'junto'), ('hablamos', 'aborto', 'legal'), ('sin', 'aborto', 'legal'), ('contra', 'aborto', 'legal'), ('aborto', 'legal', 'ayudó'), ('aborto', 'legal', 'c5n'), ('aborto', 'legal', 'oportunidad'), ('voto', 'aborto', 'legal'), ('aborto', 'legal', '2012'), ('aborto', 'legal', 'aborté'), ('aborto', 'legal', 'apareció'), ('aborto', 'legal', 'conversación'), ('aborto', 'legal', 'denunciaron'), ('aborto', 'legal', 'dándose'), ('aborto', 'legal', 'estigmatización'), ('aborto', 'legal', 'frente'), ('aborto', 'legal', 'implica'), ('aborto', 'legal', 'insisten'), ('aborto', 'legal', 'ln'), ('aborto', 'legal', 'lula'), ('aborto', 'legal', 'luladasilva'), ('aborto', 'legal', 'mirando')]
# - Number of nodes:1607
# - Number of edges:1723
# - ***particion 0***:
#   - tweets a favor: 424 (52.80199252801992%)
#   - tweets en contra: 379 (47.19800747198008%)
# - ***particion 1***:
#   - tweets a favor: 398 (49.50248756218906%)
#   - tweets en contra: 406 (50.49751243781094%)
#
# ---
#
# - ***features***: 100 top trigrams with likelihood_ratio
# [('no', 'aborto', 'legal'), ('aborto', 'legal', 'seguro'), ('aborto', 'aborto', 'legal'), ('avilma', 'aborto', 'legal'), ('debate', 'aborto', 'legal'), ('favor', 'aborto', 'legal'), ('despenalización', 'aborto', 'legal'), ('verde', 'aborto', 'legal'), ('x', 'aborto', 'legal'), ('aborto', 'legal', 'ahora'), ('aborto', 'legal', 'abortolegalya'), ('y', 'aborto', 'legal'), ('vida', 'aborto', 'legal'), ('debatiendo', 'aborto', 'legal'), ('ygratuito', 'aborto', 'legal'), ('aborto', 'legal', 'dorso'), ('aborto', 'legal', 'vida'), ('aborto', 'legal', 'y'), ('abortolegalseguroygratuito', 'aborto', 'legal'), ('aborto', 'legal', 'derechoadecidir'), ('legal', 'aborto', 'legal'), ('aborto', 'legal', 'ciencia'), ('aborto', 'legal', 'banco'), ('congreso', 'aborto', 'legal'), ('ley', 'aborto', 'legal'), ('aborto', 'legal', 'argentina'), ('aborto', 'legal', 'corazón'), ('aborto', 'legal', 'flecha'), ('aborto', 'legal', 'junto'), ('hablamos', 'aborto', 'legal'), ('sin', 'aborto', 'legal'), ('contra', 'aborto', 'legal'), ('aborto', 'legal', 'ayudó'), ('aborto', 'legal', 'c5n'), ('aborto', 'legal', 'oportunidad'), ('voto', 'aborto', 'legal'), ('aborto', 'legal', '2012'), ('aborto', 'legal', 'aborté'), ('aborto', 'legal', 'apareció'), ('aborto', 'legal', 'conversación'), ('aborto', 'legal', 'denunciaron'), ('aborto', 'legal', 'dándose'), ('aborto', 'legal', 'estigmatización'), ('aborto', 'legal', 'frente'), ('aborto', 'legal', 'implica'), ('aborto', 'legal', 'insisten'), ('aborto', 'legal', 'ln'), ('aborto', 'legal', 'lula'), ('aborto', 'legal', 'luladasilva'), ('aborto', 'legal', 'mirando'), ('aborto', 'legal', 'panorama'), ('aborto', 'legal', 'participa'), ('aborto', 'legal', 'pentecostales'), ('aborto', 'legal', 'prohibición'), ('aborto', 'legal', 'sabe'), ('aborto', 'legal', 'tarea'), ('anacer', 'aborto', 'legal'), ('aprueba', 'aborto', 'legal'), ('barrancos', 'aborto', 'legal'), ('charlar', 'aborto', 'legal'), ('confiable', 'aborto', 'legal'), ('conquistar', 'aborto', 'legal'), ('conversando', 'aborto', 'legal'), ('defendiendo', 'aborto', 'legal'), ('distancia', 'aborto', 'legal'), ('imbéciles', 'aborto', 'legal'), ('internacional', 'aborto', 'legal'), ('mayúsculas', 'aborto', 'legal'), ('mesazo', 'aborto', 'legal'), ('pelotudx', 'aborto', 'legal'), ('penalizada', 'aborto', 'legal'), ('periodismo', 'aborto', 'legal'), ('porotos', 'aborto', 'legal'), ('toca', 'aborto', 'legal'), ('ángulo', 'aborto', 'legal'), ('legalizar', 'aborto', 'legal'), ('ripoll', 'aborto', 'legal'), ('exposiciones', 'aborto', 'legal'), ('abortolegalya', 'aborto', 'legal'), ('aborto', 'legal', 'cada'), ('aborto', 'legal', 'https'), ('lucha', 'aborto', 'legal'), ('aborto', 'legal', 'nicolás'), ('derecho', 'aborto', 'legal'), ('aborto', 'legal', 'mujeres'), ('salud', 'aborto', 'legal'), ('aborto', 'legal', 'calle'), ('aborto', 'legal', 'cdmx'), ('aborto', 'legal', 'creencias'), ('aborto', 'legal', 'esi'), ('aborto', 'legal', 'faltazo'), ('aborto', 'legal', 'lleva'), ('aborto', 'legal', 'nuevas'), ('aborto', 'legal', 'reuniones'), ('aborto', 'legal', 'viene'), ('cobertura', 'aborto', 'legal'), ('discute', 'aborto', 'legal'), ('escritoras', 'aborto', 'legal'), ('feminista', 'aborto', 'legal'), ('metan', 'aborto', 'legal')]
# - Number of nodes:1607
# - Number of edges:1783
# - ***particion 0***:
#   - tweets a favor: 412 (51.30759651307597%)
#   - tweets en contra: 391 (48.692403486924036%)
# - ***particion 1***:
#   - tweets a favor: 410 (50.99502487562189%)
#   - tweets en contra: 394 (49.004975124378106%)
#
# ---
#
# - ***features***: 20 top quadgrams with likelihood_ratio
# [('aborto', 'legal', 'aborto', 'legal'), ('no', 'aborto', 'legal', 'patriarcado'), ('vilma', 'no', 'aborto', 'legal'), ('no', 'aborto', 'legal', 'salvemos'), ('aborto', 'no', 'aborto', 'legal'), ('aborto', 'legal', 'no', 'aborto'), ('banco', 'avilma', 'aborto', 'legal'), ('aborto', 'legal', 'banco', 'avilma'), ('aborto', 'legal', 'salvemos', 'las2'), ('las2', 'vidas', 'aborto', 'legal'), ('aborto', 'legal', 'dorso', 'mano'), ('corazón', 'verde', 'aborto', 'legal'), ('aborto', 'legal', 'corazón', 'verde'), ('aborto', 'legal', 'educación', 'sexual'), ('vida', 'imbéciles', 'aborto', 'legal'), ('vida', 'lasmujer', 'aborto', 'legal'), ('vida', 'po', 'aborto', 'legal'), ('aborto', 'legal', 'seguro', 'ygratuito'), ('aborto', 'legal', 'pro', 'vida'), ('aborto', 'legal', 'y', 'gratuito')]
# - Number of nodes:1607
# - Number of edges:511
# - ***particion 0***:
#   - tweets a favor: 421 (52.42839352428393%)
#   - tweets en contra: 382 (47.57160647571607%)
# - ***particion 1***:
#   - tweets a favor: 401 (49.875621890547265%)
#   - tweets en contra: 403 (50.124378109452735%)
#
# ---
#
# - ***features***: 50 top quadgrams with likelihood_ratio
# [('aborto', 'legal', 'aborto', 'legal'), ('no', 'aborto', 'legal', 'patriarcado'), ('vilma', 'no', 'aborto', 'legal'), ('no', 'aborto', 'legal', 'salvemos'), ('aborto', 'no', 'aborto', 'legal'), ('aborto', 'legal', 'no', 'aborto'), ('banco', 'avilma', 'aborto', 'legal'), ('aborto', 'legal', 'banco', 'avilma'), ('aborto', 'legal', 'salvemos', 'las2'), ('las2', 'vidas', 'aborto', 'legal'), ('aborto', 'legal', 'dorso', 'mano'), ('corazón', 'verde', 'aborto', 'legal'), ('aborto', 'legal', 'corazón', 'verde'), ('aborto', 'legal', 'educación', 'sexual'), ('vida', 'imbéciles', 'aborto', 'legal'), ('vida', 'lasmujer', 'aborto', 'legal'), ('vida', 'po', 'aborto', 'legal'), ('aborto', 'legal', 'seguro', 'ygratuito'), ('aborto', 'legal', 'pro', 'vida'), ('aborto', 'legal', 'y', 'gratuito'), ('aborto', 'legal', 'seguro', 'y'), ('aborto', 'legal', 'santa', 'fe'), ('santa', 'fe', 'aborto', 'legal'), ('aborto', 'legal', 'bíceps', 'flexionado'), ('y', 'gratuito', 'aborto', 'legal'), ('aborto', 'legal', 'y', 'vida'), ('aborto', 'legal', 'favor', 'vida'), ('aborto', 'legal', 'sostener', 'vida'), ('despenalización', 'aborto', 'aborto', 'legal'), ('verde', 'aborto', 'legal', 'seguro'), ('seguro', 'ygratuito', 'aborto', 'legal'), ('congreso', 'aborto', 'legal', 'seguro'), ('derecho', 'aborto', 'legal', 'seguro'), ('vida', 'aborto', 'legal', 'seguro'), ('aborto', 'aborto', 'legal', 'abortolegalya'), ('semana', 'debate', 'aborto', 'legal'), ('legal', 'aborto', 'legal', 'seguro'), ('anacer', 'aborto', 'legal', 'seguro'), ('aborto', 'aborto', 'legal', 'aborto'), ('aborto', 'legal', 'aborto', 'aborto'), ('hilo', 'aborto', 'aborto', 'legal'), ('aborto', 'aborto', 'legal', 'no'), ('medicina', 'aborto', 'aborto', 'legal'), ('marcha', 'aborto', 'legal', 'seguro'), ('marco', 'debate', 'aborto', 'legal'), ('pañuelo', 'verde', 'aborto', 'legal'), ('partetres', 'aborto', 'legal', 'seguro'), ('prevenir', 'aborto', 'legal', 'seguro'), ('aborto', 'legal', 'no', 'morir'), ('salud', 'aborto', 'legal', 'seguro')]
# - Number of nodes:1607
# - Number of edges:690
# - ***particion 0***:
#   - tweets a favor: 436 (54.29638854296388%)
#   - tweets en contra: 367 (45.70361145703611%)
# - ***particion 1***:
#   - tweets a favor: 386 (48.00995024875622%)
#   - tweets en contra: 418 (51.99004975124378%)
#
# ---
#
# - ***features***: 100 top quadgrams with likelihood_ratio
# [('aborto', 'legal', 'aborto', 'legal'), ('no', 'aborto', 'legal', 'patriarcado'), ('vilma', 'no', 'aborto', 'legal'), ('no', 'aborto', 'legal', 'salvemos'), ('aborto', 'no', 'aborto', 'legal'), ('aborto', 'legal', 'no', 'aborto'), ('banco', 'avilma', 'aborto', 'legal'), ('aborto', 'legal', 'banco', 'avilma'), ('aborto', 'legal', 'salvemos', 'las2'), ('las2', 'vidas', 'aborto', 'legal'), ('aborto', 'legal', 'dorso', 'mano'), ('corazón', 'verde', 'aborto', 'legal'), ('aborto', 'legal', 'corazón', 'verde'), ('aborto', 'legal', 'educación', 'sexual'), ('vida', 'imbéciles', 'aborto', 'legal'), ('vida', 'lasmujer', 'aborto', 'legal'), ('vida', 'po', 'aborto', 'legal'), ('aborto', 'legal', 'seguro', 'ygratuito'), ('aborto', 'legal', 'pro', 'vida'), ('aborto', 'legal', 'y', 'gratuito'), ('aborto', 'legal', 'seguro', 'y'), ('aborto', 'legal', 'santa', 'fe'), ('santa', 'fe', 'aborto', 'legal'), ('aborto', 'legal', 'bíceps', 'flexionado'), ('y', 'gratuito', 'aborto', 'legal'), ('aborto', 'legal', 'y', 'vida'), ('aborto', 'legal', 'favor', 'vida'), ('aborto', 'legal', 'sostener', 'vida'), ('despenalización', 'aborto', 'aborto', 'legal'), ('verde', 'aborto', 'legal', 'seguro'), ('seguro', 'ygratuito', 'aborto', 'legal'), ('congreso', 'aborto', 'legal', 'seguro'), ('derecho', 'aborto', 'legal', 'seguro'), ('vida', 'aborto', 'legal', 'seguro'), ('aborto', 'aborto', 'legal', 'abortolegalya'), ('semana', 'debate', 'aborto', 'legal'), ('legal', 'aborto', 'legal', 'seguro'), ('anacer', 'aborto', 'legal', 'seguro'), ('aborto', 'aborto', 'legal', 'aborto'), ('aborto', 'legal', 'aborto', 'aborto'), ('hilo', 'aborto', 'aborto', 'legal'), ('aborto', 'aborto', 'legal', 'no'), ('medicina', 'aborto', 'aborto', 'legal'), ('marcha', 'aborto', 'legal', 'seguro'), ('marco', 'debate', 'aborto', 'legal'), ('pañuelo', 'verde', 'aborto', 'legal'), ('partetres', 'aborto', 'legal', 'seguro'), ('prevenir', 'aborto', 'legal', 'seguro'), ('aborto', 'legal', 'no', 'morir'), ('salud', 'aborto', 'legal', 'seguro'), ('abort', 'aborto', 'legal', 'seguro'), ('aborto', 'aborto', 'legal', 'pro'), ('aborto3causales', 'aborto', 'legal', 'seguro'), ('c5n', 'aborto', 'legal', 'seguro'), ('aborto', 'aborto', 'legal', 'abortolegal'), ('pañuelo', 'aborto', 'legal', 'seguro'), ('conciencia', 'aborto', 'legal', 'seguro'), ('permitir', 'aborto', 'aborto', 'legal'), ('defendemos', 'aborto', 'aborto', 'legal'), ('derechos', 'humanos', 'aborto', 'legal'), ('aborto', 'legal', 'flecha', 'hacia'), ('vilma', 'ripoll', 'aborto', 'legal'), ('aborto', 'aborto', 'legal', 'favor'), ('pentecostal', 'favor', 'aborto', 'legal'), ('debate', 'aborto', 'legal', 'flecha'), ('aborto', 'legal', 'nuestra', 'compañera'), ('aborto', 'legal', 'vida', 'aborto'), ('avilma', 'aborto', 'legal', 'banco'), ('avilma', 'aborto', 'legal', 'argentina'), ('pierdas', 'debate', 'aborto', 'legal'), ('debate', 'aborto', 'legal', 'junto'), ('no', 'morir', 'aborto', 'legal'), ('aborto', 'legal', 'aborto', 'si'), ('atr', 'x', 'aborto', 'legal'), ('abortar', 'y', 'aborto', 'legal'), ('aborto', 'legal', 'buen', 'lunes'), ('avilma', 'aborto', 'legal', 'prohibición'), ('martes', 'verde', 'aborto', 'legal'), ('aborto', 'legal', 'favor', 'aborto'), ('avilma', 'aborto', 'legal', 'dejar'), ('debate', 'aborto', 'legal', 'y'), ('avilma', 'aborto', 'legal', 'no'), ('debate', 'aborto', 'legal', 'panorama'), ('actividades', 'congreso', 'aborto', 'legal'), ('avilma', 'aborto', 'legal', 'buenlunes'), ('avilma', 'aborto', 'legal', 'decían'), ('avilma', 'aborto', 'legal', 'aguante'), ('avilma', 'aborto', 'legal', 'muchas'), ('legal', 'vida', 'aborto', 'legal'), ('aborto', 'legal', 'selfie', 'maría'), ('bancoa', 'avilma', 'aborto', 'legal'), ('avilma', 'aborto', 'legal', 'siempre'), ('aborto', 'legal', 'marco', 'debate'), ('mañana', 'debate', 'aborto', 'legal'), ('avilma', 'aborto', 'legal', 'ht'), ('favor', 'aborto', 'legal', 'pentecostales'), ('favor', 'aborto', 'legal', 'tarea'), ('avilma', 'aborto', 'legal', 'buen'), ('avilma', 'aborto', 'legal', 'lxs'), ('avilma', 'aborto', 'legal', 'iglesia')]
# - Number of nodes:1607
# - Number of edges:720
# - ***particion 0***:
#   - tweets a favor: 409 (50.93399750933998%)
#   - tweets en contra: 394 (49.066002490660026%)
# - ***particion 1***:
#   - tweets a favor: 413 (51.3681592039801%)
#   - tweets en contra: 391 (48.6318407960199%)
